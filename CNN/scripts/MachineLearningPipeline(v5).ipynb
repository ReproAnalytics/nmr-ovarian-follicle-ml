# %%
## Set up Environment ##

# To ensure fastai install without error, use the following commands to force installation without any requirements to get the core library
# %pip install --no-deps fastai fastcore

# Install the missing 'distutils' support
# %pip install "setuptools<65"

# Manually install critical dependencies that are compatible
# %pip install matplotlib pandas requests pyyaml packaging fastprogress

# Attempt to install a specific version of spacy that avoids the build
# %pip install spacy --only-binary=:all:

# Install openslide for downstream implemetation of WSI
# %pip install openslide-python
# Out:
# Requirement already satisfied: fastai in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.8.7)
# Requirement already satisfied: fastcore in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.12.31)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: setuptools<65 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (64.0.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.10.1)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.32.3)
# Requirement already satisfied: pyyaml in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (6.0.2)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (24.2)
# Requirement already satisfied: fastprogress in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (2024.12.14)
# Requirement already satisfied: fastcore>=1.10.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastprogress) (1.12.31)
# Requirement already satisfied: python-fasthtml>=0.12.34 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastprogress) (0.13.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: starlette~=1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-fasthtml>=0.12.34->fastprogress) (1.0.0)
# Requirement already satisfied: oauthlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-fasthtml>=0.12.34->fastprogress) (3.3.1)
# Requirement already satisfied: itsdangerous in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-fasthtml>=0.12.34->fastprogress) (2.2.0)
# Requirement already satisfied: uvicorn>=0.30 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress) (0.42.0)
# Requirement already satisfied: httpx in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-fasthtml>=0.12.34->fastprogress) (0.28.1)
# Requirement already satisfied: fastlite>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-fasthtml>=0.12.34->fastprogress) (0.2.4)
# Requirement already satisfied: python-multipart in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-fasthtml>=0.12.34->fastprogress) (0.0.22)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-fasthtml>=0.12.34->fastprogress) (4.12.3)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from starlette~=1.0->python-fasthtml>=0.12.34->fastprogress) (4.8.0)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio<5,>=3.6.2->starlette~=1.0->python-fasthtml>=0.12.34->fastprogress) (1.3.1)
# Requirement already satisfied: apswutils>=0.1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastlite>=0.1.1->python-fasthtml>=0.12.34->fastprogress) (0.1.2)
# Requirement already satisfied: apsw in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from apswutils>=0.1.2->fastlite>=0.1.1->python-fasthtml>=0.12.34->fastprogress) (3.51.3.0)
# Requirement already satisfied: click>=7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn>=0.30->uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn>=0.30->uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress) (0.14.0)
# Requirement already satisfied: httptools>=0.6.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress) (1.2.2)
# Requirement already satisfied: uvloop>=0.15.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress) (16.0)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from beautifulsoup4->python-fasthtml>=0.12.34->fastprogress) (2.6)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx->python-fasthtml>=0.12.34->fastprogress) (1.0.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: spacy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.8.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (0.24.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (2.2.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (3.1.5)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (64.0.3)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from spacy) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.12.14)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: click>=8.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.5.1)
# Requirement already satisfied: httpx>=0.24.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jinja2->spacy) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openslide-python in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.4.3)
# Requirement already satisfied: Pillow in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openslide-python) (11.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import all necessary packages
import fastai
print(fastai.__version__)

from fastai.vision.all import *
import json
import os
from pathlib import Path
from PIL import Image, ImageDraw
import pandas as pd
import numpy as np
import openslide
import torch
# Out:
# 2.8.7
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 5
#       2 import fastai
#       3 print(fastai.__version__)
# ----> 5 from fastai.vision.all import *
#       6 import json
#       7 import os
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/fastai/vision/all.py:1
# ----> 1 from . import models
#       2 from ..basics import *
#       3 from ..callback.all import *
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/fastai/vision/models/__init__.py:1
# ----> 1 from . import xresnet
#       2 from . import unet
#       3 from .tvm import *
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/fastai/vision/models/xresnet.py:7
#       3 # AUTOGENERATED! DO NOT EDIT! File to edit: ../../../nbs/11_vision.models.xresnet.ipynb.
#       4
#       5 # %% ../../../nbs/11_vision.models.xresnet.ipynb #57b6cad9
#       6 from __future__ import annotations
# ----> 7 from ...torch_basics import *
#       8 try: from torchvision.models.utils import load_state_dict_from_url
#       9 except ModuleNotFoundError: from torch.hub import load_state_dict_from_url
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/fastai/torch_basics.py:1
# ----> 1 from torch import multiprocessing
#       2 import platform,os
#       3 if platform.system()=='Darwin':
#       4     # Python 3.8 changed to 'spawn' but that doesn't work with PyTorch DataLoader w n_workers>0
#
# ModuleNotFoundError: No module named 'torch'

# %%
# Force CPU if GPU causes crashes to back up pipeline, suggested by multiple resources
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using device:", device)

# %% [markdown]
# The pathway version assumes:
# /CNN/
#     train/
#         astral/
#         atretic antral/
#         germ/
#         multilayer/
#         primary/
#         primordial/
#         stroma/
#         transitional primordial/
#     valid/
#         astral/
#         atretic antral/
#         germ/
#         multilayer/
#         primary/
#         primordial/
#         stroma/
#         transitional primordial/
#
# The test file is also located in the same path with the same structure.

# %%
# Load the QuPath tiles and build the fastai dataset loader with the pathway

path = Path('~/CNN)').expanduser()
dls = ImageDataLoaders.from_folder(
    path, 
    train = 'train',
    valid = 'valid',
    item_tfms = Resize(224), 
    batch_tfms = Normalize.from_stats(*imagenet_stats),
    bs = 16)

# Display the Qupath classification groups
print("Classes:", dls.vocab)
dls.show_batch(max_n = 6)

# %%
# Initialize the model and identifying the best resnet34 model 
# Confirm that these metircs are of interest with pretrained weights from imagenet (normalized above)

learn = cnn_learner(
    dls,
    resnet34,
    metrics = error_rate)

learn.model.to(device)

# %%
# Initiate callbacks

from fastai.callback.tracker import EarlyStoppingCallback, SaveModelCallback

early_stop = EarlyStoppingCallback(monitor='valid_loss', patience = 20)
save_best = SaveModelCallback(monitor='valid_loss', fname='best_resnet34')

## freeze and train the head of the resnet34

learn.fine_tune(
    5,
    base_lr=1e-3,
    cbs=[
        EarlyStoppingCallback(monitor='valid_loss', patience=3),
        SaveModelCallback(monitor='valid_loss', fname='best_resnet34')
    ]
)

# unfreeze the CNN and open back up to run though all the layers with a set number of epochs

learn.unfreeze()

learn.fit_one_cycle(
    10,
    lr_max=slice(1e-5, 1e-3),
    cbs=[
        EarlyStoppingCallback(monitor='valid_loss', patience=3),
        SaveModelCallback(monitor='valid_loss', fname='best_resnet34')
    ]
)

# %%
# load the best resnet34 model model 

learn.load('best_resnet34')
learn.model.eval()

# %%
# evaluate the model with a confusion matrix

interp = ClassificationInterpretation.from_learner(learn)

interp.plot_confusion_matrix()
interp.plot_top_losses(5)

# %%
# Run a subset of tiles for tile-level testing

tile_dir = Path("~/CNN/test").expanduser()

counts = {cls: 0 for cls in dls.vocab}
results = []

for img_path in tile_dir.glob("*.png"):
    pred, pred_idx, probs = learn.predict(img_path)

    counts[str(pred)] += 1

    results.append({
        "tile": str(img_path),
        "prediction": str(pred),
        "confidence": float(probs[pred_idx])
    })

pd.DataFrame(results).to_csv("tile_predictions.csv", index=False)
pd.DataFrame([counts]).to_csv("tile_counts_summary.csv", index=False)

print("Tile Counts:", counts)

# %%
###### Test on Whole Slide Images of the H. glaber dataset (MAY WANT TO DIVIDE THESE SCRIPTS) #######

# %%
# To input the larger TIFF files, install and import a WSI reader 

# %pip install openslide-python

# %%
# Tile the whole slide image before execting the CNN (remove background first)

# Remove background on an elementary level
def is_tissue(tile, threshold = 220):
    """Simple background filter"""
    arr = np.array(tile)
    return np.mean(arr) < threshold

def tile_wsi(slide, level = 0, tile_size = 224, stride = 224):
    width, height = slide.level_dimensions[level]

    tiles = []
    coords = []

    for y in range(0, height - tile_size, stride):
        for x in range(0, width - tile_size, stride):
            tile = slide.read_region((x, y), level, (tile_size, tile_size)).convert("RGB")
        if is_tissue(tile):
            tiles.append(tile)
            coords.append((x, y))

    return tiles, coords

# %%
# Actively run the trained CNN on the WSI tiles for fast WSI inference

def analyze_wsi(slide_path, learn, level = 1):
    print(f"\nProcessing: {slide_path}")
    
    slide = openslide.OpenSlide(slide_path)

    tiles, coords = tile_wsi(slide, level=level)

    if len(tiles) == 0:
        print("No tissue detected.")
        return None

    # Iniatiate rapid inference predictions in batch (make sure to set a counter)
    
    dl = learn.dls.test_dl(tiles)
    preds, _ = learn.get_preds(dl=dl)

    pred_classes = preds.argmax(dim=1)

    counts = {cls: 0 for cls in learn.dls.vocab}
    spatial_results = []
    
    for i, cls_idx in enumerate(pred_classes):
        label = learn.dls.vocab[cls_idx]
        counts[label] += 1

        x, y = coords[i]
        spatial_results.append({
            "x": x,
            "y": y,
            "prediction": label
        })

    return counts, spatial_results

# %%
# Access the .tif files from the MOTHER database using the scripts/download_mother_nmr.sh

import subprocess
from pathlib import Path

# Directory where WSI files should be stored
download_dir = Path("~/CNN/wsi").expanduser()
download_dir.mkdir(parents=True, exist_ok=True)

# Path to your .sh script (adjust if needed)
download_script = "scripts/download_mother_nmr.sh"

# Check if any .tif files already exist
tif_files = list(download_dir.rglob("*.tif"))

if len(tif_files) == 0:
    print("No WSI .tif files found. Running download script...")
    
    try:
        subprocess.run(["bash", download_script], check=True)
    except subprocess.CalledProcessError:
        raise RuntimeError("Download script failed. Check your .sh file.")
    
    # Re-scan after download
    tif_files = list(download_dir.rglob("*.tif"))
    
    if len(tif_files) == 0:
        raise RuntimeError("Download completed but no .tif files were found.")

else:
    print(f"Found {len(tif_files)} existing .tif files. Skipping download.")

# Final list of slide paths
slide_paths = tif_files

# %%
# Run through all WSI files for H. glaber pulled from the MOTHER database 

all_results = []

for slide_path in slide_paths:
    output = analyze_wsi(slide_path, learn)

    if output is None:
        continue

    counts, spatial = output

    print(f"\nResults for {Path(slide_path).name}:")
    print("Counts:", counts)

    # Save per-slide results
    slide_name = Path(slide_path).stem

    pd.DataFrame([counts]).to_csv(f"{slide_name}_counts.csv", index=False)
    pd.DataFrame(spatial).to_csv(f"{slide_name}_spatial.csv", index=False)

    all_results.append({
        "slide": slide_name,
        **counts
    })

# %%
# Save a summary of the overall pipeline 

pd.DataFrame(all_results).to_csv("all_slides_summary.csv", index=False)

print("\nPipeline complete.")
